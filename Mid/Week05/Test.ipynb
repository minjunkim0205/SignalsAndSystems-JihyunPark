# %% [markdown]
# # 문제 해결

# %% [markdown]
# ## 고조파정현파의 합

# %% [markdown]
# ### Te01
# - K = 1, 11, 49일 때, 정현파(기본주파수)와 고조파의 합 그래프 그리기

# %%
import numpy
import matplotlib.pyplot

f_s = 100 # 샘플링 주파수 100Hz
t_s = 1/f_s # 샘플링 주기(간격) 0.01sec
n_s = 300 # 샘플링 갯수, 300개
k = 3 # 하모닉스 고조파 개수(k >= 2)
# x(time)
x = numpy.arange(0, n_s) * t_s
# y(size)
y = 0
# draw
matplotlib.pyplot.title('A periodic rectangular signal x(t)=x1(t)+x2(t)+x3(t)')
for i in range(1, k+1, 2):

'''
k >= 2
3 : 2
5 : 3
7 : 4

2n+1

((k-1)/2+1)+1
'''
# Out:
# ds
# ds
